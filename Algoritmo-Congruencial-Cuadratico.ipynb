# %%
numPseudoaletorios = []
Xi = 34567
g = 23
m = pow(2,g)
a = 345
b = 234
c = 34567
ri = 0

print("valor de m = ", m)
'''
h = (b - 1) % 4
if h == 1:
    print("verdadero")
    print(h, m)
else: 
    print("falso")
'''

for i in range(800):
    Xi = ((a * (Xi ** 2)) + (b * Xi) + c) % (m)
    ri = Xi / (m - 1)
    cadenaRi = str(ri)
    extracion = cadenaRi[0:7]
    almacenamientoInt = float(extracion)
    numPseudoaletorios.append(almacenamientoInt)

print('\n'.join(map(str, numPseudoaletorios)))

f3 = open('numerosAleatoriosCuadraticos.csv','w')
for temp in numPseudoaletorios:
    f3.write(str(temp) + ', ')

f3.close()
# Out:
# valor de m =  8388608
# 0.93968
# 0.19902
# 0.15406
# 0.10204
# 0.26881
# 0.57957
# 0.33912
# 0.87645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# 0.12645
# 0.71412
# ...
